# %% [markdown]
# ## Object Detection on RTSP Stream with DeGirum PySDK
#
# This notebook demonstrates real-time object detection using DeGirum PySDK on Hailo hardware with a video stream. Simply specify the URL for your RTSP stream.

# %%
import degirum as dg, degirum_tools

zoo_url = 'degirum/deepx'
inference_host_address = '@local'
device_type = 'DEEPX/M1A'

# set model name and video source
model_name = 'yolov8n_coco--640x640_quant_deepx_m1a_1'

video_source = "../assets/Traffic.mp4" # replace with your camera rtsp stream

# load model
model = dg.load_model(
    model_name=model_name,
    inference_host_address=inference_host_address,
    zoo_url=zoo_url,
    device_type=device_type
)

# run AI inference on video stream and display the results
with degirum_tools.Display("AI Camera") as output_display:
    for inference_result in degirum_tools.predict_stream(model, video_source):
        output_display.show(inference_result.image_overlay)
# Out:
# ---------------------------------------------------------------------------
# DegirumException                          Traceback (most recent call last)
# Cell In[2], line 13
#      10 video_source = "../assets/Traffic.mp4" # replace with your camera rtsp stream
#      12 # load model
# ---> 13 model = dg.load_model(
#      14     model_name=model_name,
#      15     inference_host_address=inference_host_address,
#      16     zoo_url=zoo_url,
#      17     device_type=device_type
#      18 )
#      20 # run AI inference on video stream and display the results
#      21 with degirum_tools.Display("AI Camera") as output_display:
#
# File c:\Users\ShashiChilappagari\degirum_new\Lib\site-packages\degirum\__init__.py:244, in load_model(model_name, inference_host_address, zoo_url, token, **kwargs)
#     220 """
#     221 Load a model from the model zoo for the inference.
#     222
#    (...)    241     An instance of [degirum.model.Model][] model handling object to be used for AI inferences.
#     242 """
#     243 zoo = ZooManager(inference_host_address, zoo_url, token)
# --> 244 return zoo.load_model(model_name, **kwargs)
#
# File c:\Users\ShashiChilappagari\degirum_new\Lib\site-packages\degirum\log.py:92, in log_wrap.<locals>.sync_wrap(*args, **kwargs)
#      90 try:
#      91     logger.log(log_level, f"/ {f.__qualname__}")
# ---> 92     return f(*args, **kwargs)
#      93 finally:
#      94     t2 = time.time_ns()
#
# File c:\Users\ShashiChilappagari\degirum_new\Lib\site-packages\degirum\zoo_manager.py:327, in ZooManager.load_model(self, model_name, **kwargs)
#     265 @log_wrap
#     266 def load_model(self, model_name: str, **kwargs) -> Model:
#     267     """Create and return the model handling object for given model name.
#     268
#     269     Args:
#    (...)    325
#     326     """
# --> 327     model = self._zoo.load_model(model_name)
#     328     for key, value in kwargs.items():
#     329         if hasattr(Model, key):
#
# File c:\Users\ShashiChilappagari\degirum_new\Lib\site-packages\degirum\log.py:92, in log_wrap.<locals>.sync_wrap(*args, **kwargs)
#      90 try:
#      91     logger.log(log_level, f"/ {f.__qualname__}")
# ---> 92     return f(*args, **kwargs)
#      93 finally:
#      94     t2 = time.time_ns()
#
# File c:\Users\ShashiChilappagari\degirum_new\Lib\site-packages\degirum\_zoo_accessor.py:593, in _LocalHWCloudZooAccessor.load_model(self, model)
#     591 supported_device_types = self._model_supported_device_types(model_params)
#     592 if not supported_device_types:
# --> 593     raise DegirumException(
#     594         f"Cloud Model '{model}' does not have any supported runtime/device combinations that will work on this system."
#     595     )
#     597 return _ClientModel(
#     598     model,
#     599     model_params,
#     600     supported_device_types,
#     601     assets.model_label_dict,
#     602 )
#
# DegirumException: Cloud Model 'yolov8n_coco--640x640_quant_deepx_m1a_1' does not have any supported runtime/device combinations that will work on this system.
