# %% [markdown]
# ### Interactive Zone-Based Object Counting with DeGirum PySDK
# This script demonstrates how to perform object detection and counting within specific zones of interest using DeGirum PySDK. The key features include:
#
# - Model-Based Object Detection: Utilizes the YOLOv8 model to detect objects such as cars, motorbikes, and trucks from a video stream.
# - Zone-Based Counting: Counts objects within user-defined polygonal zones, defined as a list of coordinates.
# - Interactive Zone Adjustment: The zones of interest can be interactively adjusted in real-time using the mouse within the display window, providing flexibility to adapt to changing scenarios.
# - Customizable Output: Supports filtering specific object classes for counting and displays results per class.
# - Stream Processing: Processes video streams, displaying both the detected objects and zone-based analytics in a dedicated window.
#
# Simply define your zones, select the classes to track, and specify the video source to get started. This script is ideal for applications such as traffic monitoring, crowd analysis, and zone-specific surveillance.

# %%
# !pip install degirum degirum_tools
# Out:
# Requirement already satisfied: degirum in /usr/local/lib/python3.11/dist-packages (0.16.0)
# Requirement already satisfied: degirum_tools in /usr/local/lib/python3.11/dist-packages (0.16.5)
# Requirement already satisfied: pyzmq>=26.1 in /usr/local/lib/python3.11/dist-packages (from degirum) (26.4.0)
# Requirement already satisfied: psutil>=6.0 in /usr/local/lib/python3.11/dist-packages (from degirum) (7.0.0)
# Requirement already satisfied: pyseccomp>=0.1 in /usr/local/lib/python3.11/dist-packages (from degirum) (0.1.2)
# Requirement already satisfied: msgpack<2.0,>=1.0.4 in /usr/local/lib/python3.11/dist-packages (from degirum) (1.1.0)
# Requirement already satisfied: msgpack-numpy==0.4.7.1 in /usr/local/lib/python3.11/dist-packages (from degirum) (0.4.7.1)
# Requirement already satisfied: numpy<2.0,>=1.22 in /usr/local/lib/python3.11/dist-packages (from degirum) (1.26.4)
# Requirement already satisfied: opencv-python<5.0,>=4.6 in /usr/local/lib/python3.11/dist-packages (from degirum) (4.11.0.86)
# Requirement already satisfied: pillow<11.0,>=9.2 in /usr/local/lib/python3.11/dist-packages (from degirum) (10.4.0)
# Requirement already satisfied: python-socketio<6.0,>=5.7 in /usr/local/lib/python3.11/dist-packages (from python-socketio[client]<6.0,>=5.7->degirum) (5.13.0)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from degirum) (6.0.2)
# Requirement already satisfied: types-PyYAML<7.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from degirum) (6.0.12.20250402)
# Requirement already satisfied: requests<3.0,>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from degirum) (2.32.3)
# Requirement already satisfied: types-requests<3.0,>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from degirum) (2.32.0.20250328)
# Requirement already satisfied: websocket-client<2.0,>=1.5.1 in /usr/local/lib/python3.11/dist-packages (from degirum) (1.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (1.14.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (1.1.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (7.34.0)
# Requirement already satisfied: pafy in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (0.5.5)
# Requirement already satisfied: youtube-dl==2020.12.2 in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (2020.12.2)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (2.0.8)
# Requirement already satisfied: ffmpegcv>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (0.3.18)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (4.13.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (4.23.0)
# Requirement already satisfied: apprise in /usr/local/lib/python3.11/dist-packages (from degirum_tools) (1.9.3)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum) (0.23.1)
# Requirement already satisfied: python-engineio>=4.11.0 in /usr/local/lib/python3.11/dist-packages (from python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.30.0->degirum) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.30.0->degirum) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.30.0->degirum) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0,>=2.30.0->degirum) (2025.1.31)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from apprise->degirum_tools) (2.0.0)
# Requirement already satisfied: click>=5.0 in /usr/local/lib/python3.11/dist-packages (from apprise->degirum_tools) (8.1.8)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from apprise->degirum_tools) (3.8)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->degirum_tools) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema->degirum_tools) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->degirum_tools) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->degirum_tools) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->degirum_tools) (0.24.0)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools->degirum_tools) (3.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->degirum_tools) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools->degirum_tools) (2.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->degirum_tools) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->degirum_tools) (0.2.13)
# Requirement already satisfied: simple-websocket>=0.10.0 in /usr/local/lib/python3.11/dist-packages (from python-engineio>=4.11.0->python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum) (1.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib->apprise->degirum_tools) (3.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools->degirum_tools) (1.17.0)
# Requirement already satisfied: wsproto in /usr/local/lib/python3.11/dist-packages (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum) (1.2.0)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto->simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio<6.0,>=5.7->python-socketio[client]<6.0,>=5.7->degirum) (0.14.0)

# %%
import degirum as dg, degirum_tools


zoo_url = 'degirum/deepx'
inference_host_address = '@cloud'
device_type = 'DEEPX/M1A'
token='dg_8PNGrkCskAPQooMPxoBRT8qBPSzac2cKoF2Qo'

# set the model name and video source
model_name = 'yolov8n_coco--640x640_quant_deepx_m1a_1'
video_source = '/content/traffic.mp4'

# define the zones of interest
polygon_zones = [
    [[265, 260], [730, 260], [870, 450], [120, 450]],
    [[400, 100], [610, 100], [690, 200], [320, 200]],
]

# define class list and display options
class_list = ["car", "motorbike", "truck"]
per_class_display = True
window_name="AI Camera"

# load model
model = dg.load_model(
    model_name=model_name,
    inference_host_address=inference_host_address,
    zoo_url=zoo_url,
    token=token,
    overlay_color=[(255,0,0)],
    output_class_set = set(class_list)
)

# create zone counter
zone_counter = degirum_tools.ZoneCounter(
        polygon_zones,
        class_list=class_list,
        per_class_display=per_class_display,
        triggering_position=degirum_tools.AnchorPoint.CENTER,
        window_name=window_name,  # attach display window for interactive zone adjustment
)

# attach zone counter to model
degirum_tools.attach_analyzers(model, [zone_counter])

# run inference and display results
with degirum_tools.Display(window_name) as display:
    for inference_result in degirum_tools.predict_stream(model, video_source,):
        display.show(inference_result)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
